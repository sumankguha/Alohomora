# %% [markdown]
# # IVSA analysis of cohort01 (AM-ICSS group)
#
# **Note:**
# Edits made to IVSA original file !2019-04-05 to remove data of Cohort02
#
# **METADATA:**
#
# |Sex    | ICSS+ShA | ICSS+LgA      |
# |:-----:|:--------:|:-------------:|
# |Males  | NULL     | NC1, NC3,     |
# |-------|----------|---------------|
# |Females| NULL     | NC4, NC6, NC8 |
# |-------|----------|---------------|
#
# **OUTLINE:**
#
# ---

# %%
# %load_ext rpy2.ipython

# %%
# %%capture
# %%R
library(tidyverse)
library(lubridate)

# %% [markdown]
# ---
# ## 1. Load data

# %%
# %%capture
# %%R
IVSA_dataDir <- "~/Dropbox (Partners HealthCare)/Projects/R01_2017_OxycSA-NASh-Glutamate/_data_R01_2017/_data_R01_2017_IVSA/Male-Female/ShA+LgA/AM_ICSS/Cohort02/_csvFiles"
IVSA_data <- read_csv(file.path(IVSA_dataDir,"_ivsaData_am_cohort02.csv"))

# %%
# %%R
# IVSA_data %>% print
# Out:
# # A tibble: 17,882 x 7
#    date       cohort    regimen group   subjectID eventType eventTime
#    <date>     <chr>     <chr>   <chr>   <chr>     <chr>         <dbl>
#  1 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards           4
#  2 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards          16
#  3 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards          50
#  4 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards          69
#  5 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards         456
#  6 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards         467
#  7 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards         479
#  8 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards        1569
#  9 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards        2571
# 10 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards        2596
# # ... with 17,872 more rows

# %%
# %%R
# # This needs to be defined after loading the dataset
# # Ideal data types
# # date   |  cohort  | regimen  |   group  |  subjectID   |  eventType  | eventTime
# # <date> | <factor> | <factor> | <factor> |   <factor>   |   <factor>  |  <num>
# IVSA_data$cohort <- IVSA_data$cohort %>% as.factor
# IVSA_data$regimen <- IVSA_data$regimen %>% as.factor
# IVSA_data$group <- IVSA_data$group %>% as.factor
# IVSA_data$subjectID <- IVSA_data$subjectID %>% as.factor
# IVSA_data$eventType <- IVSA_data$eventType %>% as.factor
# IVSA_data %>% print
# Out:
# # A tibble: 17,882 x 7
#    date       cohort    regimen group   subjectID eventType eventTime
#    <date>     <fct>     <fct>   <fct>   <fct>     <fct>         <dbl>
#  1 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards           4
#  2 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards          16
#  3 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards          50
#  4 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards          69
#  5 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards         456
#  6 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards         467
#  7 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards         479
#  8 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards        1569
#  9 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards        2571
# 10 2018-11-01 ICSS+IVSA 1H      FEMALES NC4       rewards        2596
# # ... with 17,872 more rows

# %% [markdown]
# ---
# ## 2. Annotate data

# %% [markdown]
# ---
# ## 2. Overview and data integrity check

# %%
# %%R
# IVSA_data$cohort %>% unique
# Out:
# [1] ICSS+IVSA
# Levels: ICSS+IVSA

# %%
# %%R
# IVSA_data$regimen %>% unique
# Out:
# [1] 1H 6H 3H
# Levels: 1H 3H 6H

# %%
# %%R
# IVSA_data$group %>% unique
# Out:
# [1] FEMALES MALES
# Levels: FEMALES MALES

# %%
# %%R
# IVSA_data$subjectID %>% unique
# Out:
# [1] NC4 NC6 NC8 NC1 NC3 NC7
# Levels: NC1 NC3 NC4 NC6 NC7 NC8

# %%
# %%R
# IVSA_data$eventType %>% unique
# Out:
# [1] rewards     corrLever   incorrLever
# Levels: corrLever incorrLever rewards

# %% [markdown]
# ---
# ## 3. Plot individual animals

# %%
# %%R -w 640 -h 320
# IVSA_data %>%
# filter(eventType == "rewards" & subjectID != "NC7") %>% select(date, cohort, group, subjectID, eventTime) %>%
# group_by(date, cohort, group, subjectID) %>%
# summarise(infusions = n()) %>% ungroup %>%
# ggplot(aes(x = date, y = infusions, color = subjectID, fill = subjectID, shape = group)) +
# geom_jitter(alpha = 0.5, size = 3) + geom_line() +
# ylim(0, 200) +
# facet_wrap(vars(cohort)) +
# theme_minimal()

# %%
# %%R -w 640 -h 320
# IVSA_data %>%
# filter(eventType == "corrLever" | eventType == "incorrLever") %>% filter(subjectID != "NC7") %>% select(date, cohort, group, subjectID, eventTime) %>%
# group_by(date, cohort, group, subjectID) %>%
# summarise(totalLeverPresses = n()) %>% ungroup %>%
# ggplot(aes(x = date, y = totalLeverPresses, color = subjectID, fill = subjectID, shape = group)) +
# geom_jitter(alpha = 0.5, size = 3) + geom_line() +
# facet_wrap(vars(cohort)) +
# theme_minimal()

# %%
# %%R -w 640 -h 320
# IVSA_data %>%
# filter(eventType == "corrLever" & subjectID != "NC7") %>% select(date, cohort, group, subjectID, eventTime) %>%
# group_by(date, cohort, group, subjectID) %>%
# summarise(activeLeverPresses = n()) %>% ungroup %>%
# ggplot(aes(x = date, y = activeLeverPresses, color = subjectID, fill = subjectID, shape = group)) +
# geom_jitter(alpha = 0.5, size = 3) + geom_line() +
# facet_wrap(vars(cohort)) +
# theme_minimal()

# %%
# %%R -w 640 -h 320
# IVSA_data %>%
# filter(eventType == "incorrLever" & subjectID != "NC7") %>% select(date, cohort, group, subjectID, eventTime) %>%
# group_by(date, cohort, group, subjectID) %>%
# summarise(inactiveLeverPresses = n()) %>% ungroup %>%
# ggplot(aes(x = date, y = inactiveLeverPresses, color = subjectID, fill = subjectID, shape = group)) +
# geom_jitter(alpha = 0.5, size = 3) + geom_line() +
# ylim(0, 600) +
# facet_wrap(vars(cohort)) +
# theme_minimal()

# %% [markdown]
# ---
# ## 4. Plot group-wise data
# ### 4.1. Scatter and line plots

# %% [markdown]
# ### 4.2. Mean +/- SEM plots
